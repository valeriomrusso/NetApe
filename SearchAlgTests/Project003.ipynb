# %%
import gym
import minihack
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as display

# %%
from utils import *
from algorithms import bfs, a_star
import montecarlo_algorithm

# %%
#Create our environment specifying the Map and what keys we have to observe 
env = gym.make("MiniHack-ExploreMaze-Hard-Mapped-v0", observation_keys=("chars", "pixel", "blstats", "message"))
state = env.reset()

coordinates = [500, 500]

plt.imshow(state['pixel'][:coordinates[0], :coordinates[1]])

game_map = state['chars']
game = state['pixel']
game_stats = state['blstats']
game_mex = state['message']

game_map = np.array(game_map)

start = get_player_location(game_map)
target = get_target_location(game_map)
hp = game_stats[6]
print("Agent position:", start)
print("Target position:", target)


# Add Game Over function
def display_game_over():
    plt.text(0.5, 0.5, "Game Over: You were killed by monsters!", 
             fontsize=20, ha='center', va='center', color='red', transform=plt.gca().transAxes)

# Add ictory function
def display_victory():
    plt.text(0.5, 0.5, "Victory: You reached the target!", 
             fontsize=20, ha='center', va='center', color='green', transform=plt.gca().transAxes)

path = montecarlo_algorithm.mcts(env, start, target)
print("Computed Path:", path)

# Pass the path to `actions_from_path` if it expects a list of actions
actions = actions_from_path(start, path[1:])

image = plt.imshow(game[:coordinates[0], :coordinates[1]])
for action in actions:
    s, _, done, _ = env.step(action)  # `done` say to us when the simulation is over
    image.set_data(s['pixel'][:coordinates[0], :coordinates[1]])
    
    
    # If the simulation is done
    if done:
        # If player's hp are equal to 0 it means that he is dead
        if hp == 0: 
            display_game_over()
            break  # Interrupt the smulation

        # Else you have won    
        display_victory()
        break  # Interrupt the smulation


    # Update the game visualization
    display.display(plt.gcf())
    display.clear_output(wait=True)
# Out:
# Agent position: (6, 1)
# Target position: (11, 14)
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Error during expansion: Called step on finished NetHack
# Computed Path: [(6, 1), (5, 1), (4, 1), (3, 1)]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 41
#      39 image = plt.imshow(game[:coordinates[0], :coordinates[1]])
#      40 for action in actions:
# ---> 41     s, _, done, _ = env.step(action)  # `done` say to us when the simulation is over
#      42     image.set_data(s['pixel'][:coordinates[0], :coordinates[1]])
#      45     # If the simulation is done
#
# File ~/UniProjects/AIF/NetApe/MINIHACKtests/minihack/minihack/base.py:396, in MiniHack.step(self, action)
#     393 self._previous_action = action
#     394 # Within this call, _is_episode_end is called and then _reward_fn,
#     395 # both using self.reward_manager
# --> 396 return super().step(action)
#
# File ~/UniProjects/AIF/NetApe/NLEtests/nle/nle/env/base.py:359, in NLE.step(self, action)
#     356 # Careful: By default we re-use Numpy arrays, so copy before!
#     357 last_observation = tuple(a.copy() for a in self.last_observation)
# --> 359 observation, done = self.nethack.step(self.actions[action])
#     360 is_game_over = observation[self._program_state_index][0] == 1
#     361 if is_game_over or not self._allow_all_modes:
#
# File ~/UniProjects/AIF/NetApe/NLEtests/nle/nle/nethack/nethack.py:250, in Nethack.step(self, action)
#     249 def step(self, action):
# --> 250     self._pynethack.step(action)
#     251     return self._step_return(), self._pynethack.done()
#
# RuntimeError: Called step on finished NetHack
